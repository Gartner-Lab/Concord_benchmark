# %%
library(Seurat)
pyenv = 'concord'
library(anndata)
library(reticulate)
library(VisCello)
use_condaenv(pyenv, required = TRUE)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
# 'SeuratObject' was built under R 4.4.0 but the current version is
# 4.4.2; it is recomended that you reinstall 'SeuratObject' as the ABI
# for R may have changed
#
# 'SeuratObject' was built with package 'Matrix' 1.7.0 but the current
# version is 1.7.1; it is recomended that you reinstall 'SeuratObject' as
# the ABI for 'Matrix' may have changed
#
#
# Attaching package: 'SeuratObject'
#
#
# The following objects are masked from 'package:base':
#
#     intersect, t
#
#
#
# Attaching package: 'anndata'
#
#
# The following object is masked from 'package:SeuratObject':
#
#     Layers
#
#
# Loading required package: shiny
#
# Loading required package: shinyBS
#
# Loading required package: shinycssloaders
#
# Loading required package: devtools
#
# Loading required package: usethis
#
# Loading required package: shinyWidgets
#
# Loading required package: htmlwidgets
#
#
# Attaching package: 'htmlwidgets'
#
#
# ...

# %%
eset_cc = readRDS("../data/intestine_dev/cello_benchmark_Huycke_cc__Jan09-1846/eset.rds")

# %%
fmeta <- fData(eset_cc)
pmeta <- pData(eset_cc)
fmeta
# Out:
#          gene_short_name
# Pcna     Pcna
# Cdc45    Cdc45
# Ubr7     Ubr7
# Tyms     Tyms
# Chaf1b   Chaf1b
# Mcm5     Mcm5
# Pola1    Pola1
# Casp8ap2 Casp8ap2
# Slbp     Slbp
# Clspn    Clspn
# Usp1     Usp1
# Rfc2     Rfc2
# Fen1     Fen1
# Hells    Hells
# Dtl      Dtl
# Gmnn     Gmnn
# Rrm1     Rrm1
# Rad51    Rad51
# Brip1    Brip1
# Rrm2     Rrm2
# Wdr76    Wdr76
# Rpa2     Rpa2
# Blm      Blm
# Rad51ap1 Rad51ap1
# Nasp     Nasp
# Uhrf1    Uhrf1
# Ung      Ung
# Tipin    Tipin
# Ccne2    Ccne2
# Prim1    Prim1
# ...      ...
# Ncapd2   Ncapd2
# Tacc3    Tacc3
# Cks2     Cks2
# Ccnb2    Ccnb2
# Cenpe    Cenpe
# Cdca3    Cdca3
# Ect2     Ect2
# Hmmr     Hmmr
# Mki67    Mki67
# Kif2c    Kif2c
# Bub1     Bub1
# Kif20b   Kif20b
# Ctcf     Ctcf
# Kif23    Kif23
# Nusap1   Nusap1
# Anln     Anln
# Cdc20    Cdc20
# Tmpo     Tmpo
# Lbr      Lbr
# Ckap2l   Ckap2l
# Cks1b    Cks1b
# Ckap5    Ckap5
# Cdca2    Cdca2
# Smc4     Smc4
# Top2a    Top2a
# Cenpa    Cenpa
# Psrc1    Psrc1
# ...

# %%
write.csv(fmeta, file = "../data/intestine_dev/cello_benchmark_Huycke_cc__Jan09-1846/fmeta.csv")
